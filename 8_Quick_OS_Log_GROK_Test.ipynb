# %%
from pygrok import Grok

# %% [markdown]
# # Using Grok for string matching and clustering OS Logs to pre-defined rules

# %%
patterns = []
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}avahi-autoipd.*Callout.*,%{SPACE}address%{SPACE}%{IP:src_ip_address}.*')# 0
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}avahi-autoipd.*Starting.*%{SPACE}address%{SPACE}%{IP:src_ip_address}.*')# 1
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}avahi-autoipd.*Successfully.*%{SPACE}address%{SPACE}%{IP:src_ip_address}.*')# 2
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Accepted%{SPACE}password%{SPACE}for%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 3
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Accepted%{SPACE}password%{SPACE}for%{SPACE}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 4
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Accepted%{SPACE}publickey%{SPACE}for%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 5
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Accepted%{SPACE}publickey%{SPACE}for%{SPACE}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 6
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Connection%{SPACE}closed%{SPACE}by%{SPACE}%{IP:src_ip_address}.*')# 7
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Connection%{SPACE}reset%{SPACE}by%{SPACE}%{IP:src_ip_address}.*')# 8
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Disconnected%{SPACE}from%{SPACE}%{IPORHOST:src_ip_address}.*')# 9
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*error:%{SPACE}maximum%{SPACE}authentication%{SPACE}attempts%{SPACE}exceeded%{SPACE}for%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 10
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*error:%{SPACE}maximum%{SPACE}authentication%{SPACE}attempts%{SPACE}exceeded%{SPACE}for%{SPACE}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 11
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Failed%{SPACE}none%{SPACE}for%{SPACE}invalid%{SPACE}user%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 12
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Failed%{SPACE}none%{SPACE}for%{SPACE}invalid%{SPACE}user%{SPACE}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 13
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Failed%{SPACE}password%{SPACE}for%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 14
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Failed%{SPACE}password%{SPACE}for%{SPACE}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 15
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}packet_write_wait:%{SPACE}Connection%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 16
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}input_userauth_request: invalid%{SPACE}user%{SPACE}%{IP:src_ip_address}.*')# 17 
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}PAM.*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}%{USER:local_user}.*')# 18
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}PAM.*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}.*')# 19
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}pam_unix\(sshd:auth\).*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}%{USER:local_user}.*')# 20
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}pam_unix\(sshd:auth\).*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}.*')# 21
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}Received%{SPACE}disconnect%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 22
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}ssh_dispatch_run_fatal:%{SPACE}Connection%{SPACE}from%{SPACE}%{IP:src_ip_address}.*')# 23
patterns.append('%{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}Unable%{SPACE}to%{SPACE}negotiate%{SPACE}with%{SPACE}%{IP:src_ip_address}.*') # 24

# %%
def process(line, annotated_ips_l1):
    for j, ptrn in enumerate(patterns):
        gork_match = Grok(ptrn).match(line)
        if (gork_match == None):
            pass
        else:
            print("Log Message")
            print(line)
            print("Pattern")
            print(ptrn,"\n")
            print("Extracted features")
            print(gork_match,"\n")
            print("*************************************")

annotated_ips_l1=[]
abs_file_path= "quick_log_test.log"
with open(abs_file_path) as f:
    for log in f:
        process(log,annotated_ips_l1)
# Out:
# Log Message
# Nov  7 06:41:25 bigdata-vm-55 avahi-autoipd(ens3)[23048]: Callout BIND, address 169.254.6.247 on interface ens3
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}avahi-autoipd.*Callout.*,%{SPACE}address%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '169.254.6.247'}
#
# *************************************
# Log Message
# Nov  7 06:41:29 bigdata-vm-55 avahi-autoipd(ens3)[23048]: Callout STOP, address 169.254.6.247 on interface ens3
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}avahi-autoipd.*Callout.*,%{SPACE}address%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '169.254.6.247'}
#
# *************************************
# Log Message
# Nov 28 01:03:13 bigdata-vm-7 avahi-autoipd(ens3)[759]: Callout UNBIND, address 169.254.6.115 on interface ens3
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}avahi-autoipd.*Callout.*,%{SPACE}address%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '169.254.6.115'}
#
# *************************************
# Log Message
# Nov  7 06:41:19 bigdata-vm-55 avahi-autoipd(ens3)[23048]: Starting with address 169.254.6.247
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}avahi-autoipd.*Starting.*%{SPACE}address%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '169.254.6.247'}
#
# *************************************
# Log Message
# Nov  7 06:41:29 bigdata-vm-55 avahi-autoipd(ens3)[23048]: Successfully claimed IP address 169.254.6.247
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}avahi-autoipd.*Successfully.*%{SPACE}address%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '169.254.6.247'}
#
# *************************************
# Log Message
# Dec  4 08:09:14 bigdata-vm-3 sshd[18922]: Accepted password for student from 185.176.221.172 port 55907 ssh2
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Accepted%{SPACE}password%{SPACE}for%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'local_user': 'student', 'src_ip_address': '185.176.221.172'}
#
# *************************************
# Log Message
# Nov 23 04:37:47 bigdata-vm-22 sshd[1259]: Accepted publickey for root from 98.156.146.24 port 61220 ssh2: RSA SHA256:VdMdQ4GrieR0LtAX2Xk0se8yUD01gPMDCaDO+LFOPyk
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Accepted%{SPACE}publickey%{SPACE}for%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'local_user': 'root', 'src_ip_address': '98.156.146.24'}
#
# *************************************
# Log Message
# Feb  8 03:58:50 bigdata-vm-6 sshd[2094]: Connection closed by 45.116.44.22 port 51070 [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Connection%{SPACE}closed%{SPACE}by%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '45.116.44.22'}
#
# *************************************
# Log Message
# Nov  6 22:01:53 bigdata-vm-49 sshd[1209]: Connection reset by 122.114.86.40 port 61176 [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Connection%{SPACE}reset%{SPACE}by%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '122.114.86.40'}
#
# *************************************
# Log Message
# Nov  7 10:08:19 bigdata-vm-8 sshd[15245]: Disconnected from 10.1.1.54 port 44458
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Disconnected%{SPACE}from%{SPACE}%{IPORHOST:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '10.1.1.54'}
#
# *************************************
# Log Message
# Nov  6 18:20:26 bigdata-vm-49 sshd[27102]: Disconnected from 186.178.63.1 port 53542 [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Disconnected%{SPACE}from%{SPACE}%{IPORHOST:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '186.178.63.1'}
#
# *************************************
# Log Message
# Nov  6 18:19:27 bigdata-vm-49 sshd[27037]: error: maximum authentication attempts exceeded for root from 186.178.63.1 port 53504 ssh2 [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*error:%{SPACE}maximum%{SPACE}authentication%{SPACE}attempts%{SPACE}exceeded%{SPACE}for%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'local_user': 'root', 'src_ip_address': '186.178.63.1'}
#
# *************************************
# Log Message
# Nov 16 17:04:19 bigdata-vm-13 sshd[12999]: Failed none for invalid user  from 23.224.2.202 port 52189 ssh2
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Failed%{SPACE}none%{SPACE}for%{SPACE}invalid%{SPACE}user%{SPACE}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '23.224.2.202'}
#
# *************************************
# Log Message
# Nov  6 22:03:51 bigdata-vm-49 sshd[1293]: Failed password for root from 122.114.86.40 port 49392 ssh2
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*Failed%{SPACE}password%{SPACE}for%{SPACE}%{USER:local_user}%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'local_user': 'root', 'src_ip_address': '122.114.86.40'}
#
# *************************************
# Log Message
# Nov 22 15:44:51 bigdata-vm-33 sshd[28247]: fatal: packet_write_wait: Connection from 122.226.181.164 port 41098: Broken pipe [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}packet_write_wait:%{SPACE}Connection%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '122.226.181.164'}
#
# *************************************
# Log Message
# Nov  7 09:54:32 bigdata-vm-7 sshd[30031]: fatal: ssh_dispatch_run_fatal: Connection from 10.1.1.54 port 56524: Broken pipe [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}ssh_dispatch_run_fatal:%{SPACE}Connection%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '10.1.1.54'}
#
# *************************************
# Log Message
# Jan  1 16:23:54 bigdata-vm-3 sshd[6141]: fatal: ssh_dispatch_run_fatal: Connection from 175.42.159.226 port 6094: incomplete message [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}ssh_dispatch_run_fatal:%{SPACE}Connection%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '175.42.159.226'}
#
# *************************************
# Log Message
# Dec 21 17:59:08 elk-master sshd[15502]: fatal: Unable to negotiate with 185.143.223.191 port 64120: no matching cipher found. Their offer: aes256-cbc,rijndael-cbc@lysator.liu.se,aes192-cbc,aes128-cbc,arcfour128,arcfour,3des-cbc,none [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}Unable%{SPACE}to%{SPACE}negotiate%{SPACE}with%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '185.143.223.191'}
#
# *************************************
# Log Message
# Feb 17 22:11:30 elk-master sshd[16667]: fatal: Unable to negotiate with 66.228.45.154 port 49922: no matching host key type found. Their offer: ssh-dss [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}Unable%{SPACE}to%{SPACE}negotiate%{SPACE}with%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '66.228.45.154'}
#
# *************************************
# Log Message
# Oct 22 12:08:33 bigdata-vm-28 sshd[16510]: fatal: Unable to negotiate with 155.64.38.121 port 61353: no matching key exchange method found. Their offer: diffie-hellman-group1-sha1,diffie-hellman-group-exchange-sha1 [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}Unable%{SPACE}to%{SPACE}negotiate%{SPACE}with%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '155.64.38.121'}
#
# *************************************
# Log Message
# Dec 21 15:27:50 bigdata-vm-54 sshd[19801]: input_userauth_request: invalid user 192.168.1.1 60020 [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}input_userauth_request: invalid%{SPACE}user%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '192.168.1.1'}
#
# *************************************
# Log Message
# Nov 17 06:27:26 bigdata-vm-19 sshd[4311]: input_userauth_request: invalid user 40.123.42.49\\n [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}input_userauth_request: invalid%{SPACE}user%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '40.123.42.49'}
#
# *************************************
# Log Message
# Nov  7 00:52:47 bigdata-vm-47 sshd[20908]: PAM 1 more authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=122.225.0.157
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}PAM.*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}.*
#
# Extracted features
# {'src_ip_address': '122.225.0.157'}
#
# *************************************
# Log Message
# Nov  6 22:01:38 bigdata-vm-49 sshd[1207]: PAM 4 more authentication failures; logname= uid=0 euid=0 tty=ssh ruser= rhost=122.114.86.40  user=root
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}PAM.*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}%{USER:local_user}.*
#
# Extracted features
# {'src_ip_address': '122.114.86.40', 'local_user': 'user'}
#
# *************************************
# Log Message
# Nov  6 22:01:38 bigdata-vm-49 sshd[1207]: PAM 4 more authentication failures; logname= uid=0 euid=0 tty=ssh ruser= rhost=122.114.86.40  user=root
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}PAM.*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}.*
#
# Extracted features
# {'src_ip_address': '122.114.86.40'}
#
# *************************************
# Log Message
# Nov  7 11:34:40 bigdata-vm-22 sshd[25513]: PAM 1 more authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=122.225.0.157  user=root
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}PAM.*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}%{USER:local_user}.*
#
# Extracted features
# {'src_ip_address': '122.225.0.157', 'local_user': 'user'}
#
# *************************************
# Log Message
# Nov  7 11:34:40 bigdata-vm-22 sshd[25513]: PAM 1 more authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=122.225.0.157  user=root
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}PAM.*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}.*
#
# Extracted features
# {'src_ip_address': '122.225.0.157'}
#
# *************************************
# Log Message
# Nov  7 00:52:47 bigdata-vm-47 sshd[20908]: PAM 1 more authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=122.225.0.157
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}PAM.*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}.*
#
# Extracted features
# {'src_ip_address': '122.225.0.157'}
#
# *************************************
# Log Message
# Nov  6 17:28:28 elk-master sshd[10484]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=188.22.19.11
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}pam_unix\(sshd:auth\).*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}.*
#
# Extracted features
# {'src_ip_address': '188.22.19.11'}
#
# *************************************
# Log Message
# Nov  6 22:02:25 bigdata-vm-49 sshd[1285]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=122.114.86.40  user=root
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}pam_unix\(sshd:auth\).*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}%{USER:local_user}.*
#
# Extracted features
# {'src_ip_address': '122.114.86.40', 'local_user': 'user'}
#
# *************************************
# Log Message
# Nov  6 22:02:25 bigdata-vm-49 sshd[1285]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=122.114.86.40  user=root
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}pam_unix\(sshd:auth\).*authentication%{SPACE}failure.*%{IP:src_ip_address}%{SPACE}.*
#
# Extracted features
# {'src_ip_address': '122.114.86.40'}
#
# *************************************
# Log Message
# Nov  6 20:20:37 bigdata-vm-16 sshd[12284]: Received disconnect from 83.175.217.26 port 50277:11: Bye Bye [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}Received%{SPACE}disconnect%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '83.175.217.26'}
#
# *************************************
# Log Message
# Nov  7 10:08:03 bigdata-vm-8 sshd[15209]: Received disconnect from 10.1.1.54 port 44342:11: disconnected by user
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}Received%{SPACE}disconnect%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '10.1.1.54'}
#
# *************************************
# Log Message
# Nov  6 18:20:37 bigdata-vm-49 sshd[27104]: Received disconnect from 186.178.63.1 port 53555:11: disconnected by user [preauth]
#
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*:%{SPACE}Received%{SPACE}disconnect%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '186.178.63.1'}
#
# *************************************
# Log Message
# Jan  2 00:48:13 bigdata-vm-42 sshd[22552]: fatal: ssh_dispatch_run_fatal: Connection from 197.9.237.83 port 38593: message authentication code incorrect [preauth]
# Pattern
# %{SYSLOGTIMESTAMP}%{SPACE}%{SYSLOGHOST}%{SPACE}.*fatal:%{SPACE}ssh_dispatch_run_fatal:%{SPACE}Connection%{SPACE}from%{SPACE}%{IP:src_ip_address}.*
#
# Extracted features
# {'src_ip_address': '197.9.237.83'}
#
# *************************************
